# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as pplt

pplt.xlabel('Date')
pplt.ylabel('Delta')
pplt.plot([1, 2, 3, 4])

# %%
from turtle import color

from matplotlib.lines import lineStyles


pplt.plot([6, 3, 9, 8, 2], marker = "H", color= 'red', linestyle = 'dashed')
pplt.show()
